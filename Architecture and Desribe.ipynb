# %%
from IPython.display import Image

# %%
Image("F:\JB_GEA\gambar.jpeg")

# %% [markdown]
# Describe
# I use tools like Jupyter notebook for python and navicat for database management.
#
# First, the reason why I using the jupyter notebook is that it's open-source and I Am familiar with it.
#
# Second, the reason I use the Navicat application is that it is easy to export or import data from various file types
#
# Third, the reason I choose CSV as the final output of a report is that it is easy to access
